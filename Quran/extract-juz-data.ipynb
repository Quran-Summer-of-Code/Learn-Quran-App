# %% [markdown]
# #### In this script we attempt to extract Juz/Surah relations

# %%
# source: https://www.ejaabat.com/question/1009
import re

text = """
عدد آيات الجزء الاول هي 184 ايه
عدد آيات الجزء الثاني هي 111 آية
عدد آيات الجزء الثالث هي 125 ايه
عدد آيات الجزء الرابع هي 132 ايه
عدد آيات الجزء الخامس هي 124 ايه
عدد آيات الجزء السادس هي 112 ايه
عدد آيات الجزء السابع هي 147 ايه
عدد آيات الجزء الثامن هي 142 ايه
عدد آيات الجزء التاسع هي 158 ايه
عدد آيات الجزء العاشر هي 128 ايه
عدد آيات الجزء الحادي عشر هي 150 ايه
عدد آيات الجزء الثاني عشر هي 170 ايه
عدد آيات الجزء الثالث عشر هي 154 ايه
عدد آيات الجزء الرابع هي 227 ايه
عدد آيات الجزء الخامس عشر هي 185 ايه
عدد آيات الجزء السادس عشر هي 270 ايه
عدد آيات الجزء السابع عشر هي 189 ايه
عدد آيات الجزء الثامن عشر هي 202 ايه
عدد آيات الجزء التاسع عشر هي 337 ايه
عدد آيات الجزء العشرين هي 170 ايه
عدد آيات الجزء الحادي وعشرين هي 178 ايه
عدد آيات الجزء الثاني والعشرين هي 169 ايه
عدد آيات الجزء الثالث والعشرين هي 356 ايه
عدد آيات الجزء الرابع والعشرين هي 174 ايه
عدد آيات الجزء الخامس والعشرين هي 245 ايه
عدد آيات الجزء السادس والعشرين هي 195 ايه
عدد آيات الجزء السابع والعشرين هي 398 ايه
عدد آيات الجزء الثامن والعشرين هي 136 ايه
عدد آيات الجزء التاسع والعشرين هي 430 ايه
عدد آيات الجزء الثلاثين هي 563 ايه
"""

juz_sizes = re.findall(r'\d+', 
 
 
 

text)
juz_sizes = [int(num) for num in juz_sizes]
sum(juz_sizes)-6236
# Out:
# 25

# %% [markdown]
# But Quran has 6236 Ayas, will rather create JSON manually [using this](https://arwordshub.com/%D9%81%D9%87%D8%B1%D8%B3-%D8%A7%D9%84%D9%82%D8%B1%D8%A7%D9%86-%D8%A7%D9%84%D9%83%D8%B1%D9%8A%D9%85-%D8%A8%D8%A7%D9%84%D8%A7%D8%AC%D8%B2%D8%A7%D8%A1/). Let's later go and fix the numbers or figure out what's wrong.

# %% [markdown]
# Okay NVM it's incomplete. I found [this book](https://www.alukah.net/books/files/book_11002/bookfile/fath_alrahmung.pdf). Hopefully, it's more credible.

# %%
juz_sizes = [
    148 - 1,
    111,
    126,
    131,
    124,
    110 - 11,
    149 + 11,
    142,
    159,
    127 + 1,
    151 - 1,
    170,
    152 + 2,
    227,
    185,
    269,
    192 - 2,
    201 + 1,
    338 + 1,
    171,
    178,
    169,
    357,
    185 - 10,
    246,
    204 - 9,
    389 + 10,
    137,
    431,
    564
]
sum(juz_sizes)-6236         # -1 because Bismillah was excluded from Fatiha
# Out:
# -1

# %% [markdown]
# Sadly didn't turn out to be as credible. Recalculated the sizes from start and end Ayas in the table and added/subbed deltas accordingly so it's correct. Anyway, now can Implement Juz feature by start/end getting global Ayah Index of each Juz

# %%
# perform cumalizesum to get index of each juz
import numpy as np
juz_indices = np.cumsum(juz_sizes)
juz_indices = np.insert(juz_indices,0,0)
juz_inds = list(juz_indices)[:-1]

# %%
juzNames = [
    "الجزء الأول",
    "الجزء الثاني",
    "الجزء الثالث",
    "الجزء الرابع",
    "الجزء الخامس",
    "الجزء السادس",
    "الجزء السابع",
    "الجزء الثامن",
    "الجزء التاسع",
    "الجزء العاشر",
    "الجزء الحادي عشر",
    "الجزء الثاني عشر",
    "الجزء الثالث عشر",
    "الجزء الرابع عشر",
    "الجزء الخامس عشر",
    "الجزء السادس عشر",
    "الجزء السابع عشر",
    "الجزء الثامن عشر",
    "الجزء التاسع عشر",
    "الجزء العشرون",
    "الجزء الحادي والعشرون",
    "الجزء الثاني والعشرون",
    "الجزء الثالث والعشرون",
    "الجزء الرابع والعشرون",
    "الجزء الخامس والعشرون",
    "الجزء السادس والعشرون",
    "الجزء السابع والعشرون",
    "الجزء الثامن والعشرون",
    "الجزء التاسع والعشرون",
    "الجزء الثلاثون"
]

juzSuras = [
    [0,1],          #1
    [1],            #2
    [1,2],          #3
    [2,3],          #4
    [3],            #5
    [3,4],          #6
    [4,5],          #7
    [5,6],          #8
    [6,7],          #9
    [7,8],          #10
    [8,9,10],       #11
    [10,11],        #12
    [11,12,13],     #13
    [14,15],        #14
    [16,17],        #15
    [17,18,19],     #16
    [20,21],        #17
    [22,23, 24],    #18
    [24,25,26],     #19
    [26,27,28],     #20
    [28,29,30,31,32], #21
    [32,33,34,35],    #22
    [35,36,37,38],    #23
    [38, 39, 40],     #24
    [40,41,42,43,44], #25
    [45, 46, 47, 48, 49, 50], #26
    [50,51,52,53,54,55,56], #27
    [57, 58, 59, 60, 61, 62, 63, 64, 65], #28
    [66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76], #29
    [77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113] #30
]

surahSplitss = [
    [[7, 1], [141, 1]],

    [[252, 142]],

    [[286, 253], [92, 1]],

    [[200, 93], [23, 1]],

    [[147, 24]],

    [[176, 148], [70, 1]],

    [[120, 71], [110, 1]],

    [[165, 111], [87, 1]],

    [[206, 88], [40, 1]],

    [[75, 41], [93, 1]],

    [[129, 94], [109, 1], [5, 1]],

    [[123, 6], [52, 1]],

    [[111, 53], [43, 1], [52, 1]],

    [[99, 1], [128, 1]],

    [[111, 1], [74, 1]],

    [[110, 75], [98, 1], [135, 1]],

    [[112, 1], [78, 1]],

    [[118, 1], [64, 1], [20, 1]],

    [[77, 21], [227, 1], [55, 1]],

    [[93, 56], [88, 1], [45, 1]],

    [[69, 46], [60, 1], [34, 1], [30, 1], [30, 1]],

    [[73, 31], [54, 1], [45, 1], [27, 1]],

    [[83, 28], [182, 1], [88, 1], [31, 1]],

    [[75, 32], [85, 1], [46, 1]],

    [[54, 47], [53, 1], [89, 1], [59, 1], [37, 1]],

    [[35, 1], [38, 1], [29, 1], [18, 1], [45, 1], [30, 1]],

    [[60, 31], [49, 1], [62, 1], [55, 1], [78, 1], [96, 1], [29, 1]],

    [[22, 1], [24, 1], [13, 1], [14, 1], [11, 1], [11, 1], [18, 1], [12, 1], [12, 1]],

    [[30, 1], [52, 1], [52, 1], [44, 1], [28, 1], [28, 1], [20, 1], [56, 1], [40, 1], [31, 1], [50, 1]],
    []
]

surahSplits = [[[x - 1 for x in inner] for inner in middle] for middle in surahSplitss]
print(len(surahSplits))


juzAltNames = [
    "الحمد لله", 
    "سيقول السفهاء", 
    "تلك الرسل", 
    "لن تنالوا البر",
    "والمحصنات",
    "لا يحب الله", 
    "لتجدن", 
    "ولو أننا نزلنا", 
    "قال الملأ", 
    "واعلموا",
    "إنما السبيل", 
    "ومامن دابة", 
    "وما أبرئ نفسي", 
    "الـر", 
    "سبحان", 
    "قال ألم", 
    "اقترب للناس", 
    "قد أفلح", 
    "وقال الذين لا يرجون", 
    "فما كان جواب قومه", 
    "ولا تجادلوا", 
    "ومن يقنت", 
    "وما أنزلنا",
    "فمن أظلم", 
    "إليه يرد", 
    "حـم", 
    "قال فما خطبكم", 
    "قد سمع", 
    "تبارك", 
    "عمّ"
]


juzIndices = [
    {
     "name": juzNames[i], 
     "juzAltName": juzAltNames[i] ,
     "ind": int(juz_inds[i]),
     "splits": surahSplits[i],
     "juzSuras": juzSuras[i]
    } 
    for i in range(len(juzNames))
]
# store in juzInfo.json
import json

with open("juzInfo.json", "w", encoding="utf-8") as f:
    json.dump(juzIndices, f, ensure_ascii=False, indent=4)
# Out:
# 30

# %%
{"0": "الجزء الأول", "1040": "الجزء التاسع", "1199": "الجزء العاشر", "1327": "الجزء الحادي عشر", "147": "الجزء الثاني", "1477": "الجزء الثاني عشر", "1647": "الجزء الثالث عشر", "1801": "الجزء الرابع عشر", "2028": "الجزء الخامس عشر", "2213": "الجزء السادس عشر", "2482": "الجزء السابع عشر", "258": "الجزء الثالث", "2672": "الجزء الثامن عشر", "2874": "الجزء التاسع عشر", "3213": "الجزء العشرون", "3384": "الجزء الحادي والعشرون", "3562": "الجزء الثاني والعشرون", "3731": "الجزء الثالث والعشرون", "384": "الجزء الرابع", "4088": "الجزء الرابع والعشرون", "4263": "الجزء الخامس والعشرون", "4509": "الجزء السادس والعشرون", "4704": "الجزء السابع والعشرون", "5103": "الجزء الثامن والعشرون", "515": "الجزء الخامس", "5240": "الجزء التاسع والعشرون", "5671": "الجزء الثلاثون", "639": "الجزء السادس", "738": "الجزء السابع", "898": "الجزء الثامن"}
